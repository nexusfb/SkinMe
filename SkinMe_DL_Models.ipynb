# %% [markdown]
# # **SKIN ME DL MODELS**

# %% [markdown]
# #**STEP 0: OVERVIEW**

# %% [markdown]
# **Authors:** Alessio Borgi, Federica Bruni, Maria Emilia Russo
#
# **Credit & Attributions:** Dataset [Harvard Dataverse](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/DBW86T) **HAM10000** (i.e., "Human Against Machine with 10000 training images").
#
# **SkinMe** is a Deep Learning Project whose aim is to detect Melanoma Cancer through CNN and LSTM.
#
# ### **TABLE OF CONTENTS:**
# - **STEP 0:** OVERVIEW
# - **STEP 1:** IMPORTS & SET-UP
#   - **STEP 1.1:** IMPORTING LIBRARIES]
#   - **STEP 1.2:** SET UP
# - **STEP 3:** DATA VISUALIZATION
#   - **STEP 3.1:** DISEASE CLASS DISTRIBUTION IN THE DATASET
#   - **STEP 3.2:** DISEASE LOCALIZATION
#   - **STEP 3.3:** PATIENT AGE
#   - **STEP 3.4:** SKIN LESION VERIFICATION
#   - **STEP 3.5:** PATIENT GENDER
# - **STEP 4:** DATASET TRAIN-TEST SPLIT
#   - **STEP 4.1:** DATASET CLASSES DECLARATION]
#   - **STEP 4.2:** DATASET TRAIN-TEST SPLIT
# - **STEP 5:** DATASET BALANCING
# - **STEP 6:** IMAGE VISUALIZATION
# - **STEP 7:** CNN MODEL
#   - **STEP 7.1:** MODEL BUILDING
#   - **STEP 7.2:** MODEL FITTING
#   - **STEP 7.3:** MODEL EVALUATION
#   - **STEP 7.4:** TESTING THE EXAMPLE
# - **STEP 8:** LSTM MODEL
#   - **STEP 8.1:** MODEL BUILDING
#   - **STEP 8.2:** MODEL FITTING
#   - **STEP 8.3:** MODEL EVALUATION
#   - **STEP 8.4:** TESTING THE EXAMPLE

# %% [markdown]
# # **STEP 1: IMPORTS & SET-UP**
#
# As a first step of our Project, we can proceed to **Import** all the necessary **Libraries** we will be using throughout the whole project and to **Set-Up** the necessary **environment** for the project to work.

# %% [markdown]
# ## **STEP 1.1: IMPORTING LIBRARIES**
#
# We import from the most general **Libraries** (like pandas and numpy for handling the Dataset and the Tensors), to the more specific ones(like imblearn.over_sampling for the balancing of the Dataset).

# %%
import PIL
import time
import keras
import random
import warnings 
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from datetime import datetime
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.utils import np_utils
import sklearn.metrics as metrics
from keras.models import Sequential
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix
from keras.layers import LSTM, Dense,Dropout
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **STEP 1.2: SET-UP**
#
# As a set-up step, you will have to **Mount** your **drive** content. In order to do this, you will have to have on your Drive, a **Folder**, named as **"SkinMeProject"**.
# Inside it, you should have two Folders:
# - **"dataset"**: This will contain:
#   - **"CNN_weights.h5"**: This file is used for retrieving and saving weights each time, in such a way to neither loose the work done by the Training nor restart from a totally not-trained CNN model.
#   - **"LSTM_weights.h5"**: This file is used for retrieving and saving weights each time, in such a way to neither loose the work done by the Training nor restart from a totally not-trained LSTM model.
#   - **"HAM10000_metadata.csv"**: This is the file that contains the metadata for the HAM10000 Dataset.
#   - **"hmnist_28_28_RGB.csv"**: This is the actual file that contains the HAM10000 Dataset.
#
# - **"test_imgs"**: This is the folder it will contain the images to test for.
#
# In the same level, we will find this file itself, named **"SkinMe_DL_Models.ipynb"**.
#
# Once we have set-up the folder, we can also save both the data and metadata path.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path='drive/MyDrive/SkinMeProject/dataset/hmnist_28_28_RGB.csv'
metadata_path='drive/MyDrive/SkinMeProject/dataset/HAM10000_metadata.csv'

# %% [markdown]
# # **STEP 2: LOADING DATASET**
#
# Once we have gone through the simple imports and set-up process, we can finally **Load** the **Data Dataset** and the **MetaData Dataset**. In this way, we can save them into Pandas Dataframes, in sucha a way to be very easy to manage.
#
# We also proceed to have a brief look on them, by printing out the first 5 samples of each.
#
# Note that, the Data Dataset will show a **5x2352** Table. This is because we have that each **sample** in the **HAM10000 Dataset** as a **28x28x3** shape (28 column pixels, 28 row pixels, and 3 color channels(R,G,B)). In the csv, these samples are **Flattened** to **one dimension**, and from this the result follows (2352=28x28x3).

# %%
dataset = pd.read_csv(data_path)
dataset.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
metadata=pd.read_csv(metadata_path)
metadata.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %% [markdown]
# # **STEP 3: DATA VISUALIZATION**
#
# Once we have Loaded the Dataset, we can proceed to do the first that we always have to do with a Dataset: study it and understanding it deeply.
#
# We know that **HAM10000** is composed of 10015 dermatoscopic images. Those images, are categorized among the most widespreaded skin lesions (each having a certain pre-defined label and a certain "nickname":
# - **akiec:** This has label **0** in the dataset and it stands for "Actinic Keratoses and Intraepithelial Carcinoma" (a.k.a. Bowen's disease).
# - **bcc:** This has label **1** in the dataset and it stands for "Basal Cell Carcinoma".
# - **bkl:** This has label **2** in the dataset and it stands for "Benign Keratosis-Like Lesions", and groups solar lentigines, seborrheic keratoses and lichen-planus like keratoses.
# - **df:** This has label **3** in the dataset and it stands for "Dermatofibroma".
# - **nv:** This has label **4** in the dataset and it stands for "Melanocytic Nevi".
# - **vasc:** This has label **5** in the dataset and it stands for "Vascular Lesions", and groups(angiomas, angiokeratomas, pyogenic granulomas and hemorrhage).
# - **mel:** This has label **6** in the dataset and it stands for "Melanoma".

# %% [markdown]
# ## **STEP 3.1: DISEASE CLASS DISTRIBUTION IN THE DATASET**
#
# Since we know that HAM10000 is classified depending on **7** classes/typologies, we can inspect the **Class Distribution in the Dataset**, in such a way to see whether one is predominant onto others. We simply proceed to build up a simple **Plot: NumberOfSamples VS ClassDisease**.
#
# In the plot below, as result, we will see that there is one particular **Class Disease** that is **more present** than the others (the "nv" (melanocytic nevi) class). This, of course, it is not a big deal, and it is due to the fact that this class of Skin Disease, is the most widespreaded in the world. However, it brings a lot of **Class Imbalance** in our dataset, due to the fact that it is, by its own, almost the **65%** of the **whole Dataset**.
#
# Therefore, this journey, has highlighted one thing that we should do in such a way to have a good result: **[Dataset Balancing](https://colab.research.google.com/drive/10CKC3qk3IbKTG34fygWmnzgDfLFuvceH#scrollTo=QWd6H5Xyaujg&line=1&uniqifier=1)**.

# %%
bar, ax = plt.subplots(figsize=(20, 10))
sns.countplot(x = 'dx', data = metadata)
plt.title('Disease Class Distribution in the Dataset', size=25)
plt.xlabel('ClassDisease', size=15)
plt.ylabel('NumberOfSamples', size=15)
plt.show()

# %% [markdown]
# ## **STEP 3.2: DISEASE LOCALIZATION**
#
# In order for better undestanding the Dataset, we can also view the different typologies of **Disease Localization**. This will not be a very important feature for us, but we have a look at it.
#
# We can see that the face, back and lower extremity, are the most predominant samples in the Dataset.

# %%
bar, ax = plt.subplots(figsize=(30, 10))
sns.histplot(metadata['localization'], color='orange')
plt.title('Disease Localization', size=25)
plt.xlabel('LocalizationDisease', size=15)
plt.ylabel('NumberOfSamples', size=15)
plt.show()

# %% [markdown]
# ## **STEP 3.3: PATIENTS AGE**
#
# In order for better undestanding the Dataset, we can also view the **Patients Age Distribution**. This will not be a very important feature for us, but we have a look at it.
#
# We can observe a **Left-Skewed Gaussian Distribution**(i.e., it presents Negative Skewness).

# %%
disease_location = metadata['age'].value_counts()
plt.figure(figsize=(20, 8))
sns.countplot(x='age', data=metadata)
plt.title('Patients Age', size=25)
plt.xlabel('Age', size=15)
plt.ylabel('NumberOfSamples', size=15)
plt.show()

# %% [markdown]
# The plot above clearly indicates the are group that is mostly affected by skin cancer, which is that of ages between 40 and 48.

# %% [markdown]
# ## **STEP 3.4: SKIN-LESION VERIFICATION**
#
# In order for better undestanding the Dataset, we can also view the **Skin Lesion Verification** typology. This will not be a very important feature for us, but we have a look at it.
#
# We can observe also here, a very unbalanced histogram, that is towards the histologycal and follow-up methodology.

# %%
disease_location = metadata['dx_type'].value_counts()
plt.figure(figsize=(20, 8))
sns.countplot(x='dx_type', data=metadata)
plt.title('Skin Lesion Verification', size=25)
plt.xlabel('VerificationMethodology', size=15)
plt.ylabel('NumberOfSamples', size=15)
plt.show()

# %% [markdown]
# By fat the most frequent locations of the body that skin cancer appeared was the back and the lower extermity, followed by the trunk, upper extermity and the abdomen.

# %% [markdown]
# ## **STEP 3.5: PATIENTS GENDER**
#
# In order for better undestanding the Dataset, we can also view the **Skin Lesion Verification** typology. This will not be a very important feature for us, but we have a look at it.
#
# We can observe here, instead, a very balanced histogram, that almost resembles the **Uniform Distribution**.

# %%
bar, ax = plt.subplots(figsize=(20, 10))
sns.countplot(x = 'sex', data = metadata)
plt.title('Patients Gender', size=25)
plt.xlabel('Sex', size=15)
plt.ylabel('NumberOfSamples', size=15)
plt.show()

# %% [markdown]
# In terms of the gender of patients that are most affected I have found that males are slightly more affected.

# %% [markdown]
# # **STEP 4: DATASET TRAIN-TEST SPLIT**
#
# Once we have done with the Dataset Deepening, we are ready to build our models.

# %% [markdown]
# ## **STEP 4.1: DATASET CLASSES DECLARATION**
#
# First of all, let's define the **Classes** that we have previously mentioned, in such a way to have them saved as a Dictionary. This will be useful for the last **Multiclassification**.

# %%
# Creation of a Dictionary for sotring the classes of Disease
classes={ 0:('akiec', 'Actinic Keratoses and Intraepithelial Carcinomae'), 
          1:('bcc' , 'basal cell carcinoma'), 
          2:('bkl', 'benign keratosis-like lesions'),
          3:('df', 'dermatofibroma'),
          4:('nv', ' melanocytic nevi'),
          5:('vasc', ' pyogenic granulomas and hemorrhage'),
          6:('mel', 'melanoma')}

# Declaration of the 80-20 Split.
fractions = np.array([0.8,0.2])

# %% [markdown]
# ## **STEP 4.2: TRAIN-TEST SPLIT**
#
# In order to do this, we proceed to **Split** the **Dataset** in two parts **Training** and **Testing** parts, following the **80-20% Rule**.
#
# This resulting split, will divide the Dataset in two parts, the first (Training), will have **8012** elements, the second one (Testing), will have **2003** elements.

# %%
# Generating a sample random row or column from the function caller dataFrame. (Shortcut for copying it).
dataset1 = dataset.sample(frac=1)
len_dataset1 = len(dataset1)

# Actual Train-Test Split.
train_set, test_set = np.array_split(dataset1, (fractions[:-1].cumsum() * len_dataset1).astype(int))
len_train_set, len_test_set = len(train_set), len(test_set) 

# Data-Label Split.
y_train = train_set['label']
x_train=train_set.drop(columns=['label'])
y_test=test_set['label']
x_test=test_set.drop(columns=['label'])
columns=list(x_train)

# %% [markdown]
# # **STEP 5: DATASET BALANCING**
#
# It's now time to face the problem we have found in the previous section: **Class Imbalance**. This problem, usually reflects an unequal distribution of classes within a dataset. For example, in our Dataset, most of the samples are from one class(65% of all the samples) and a very few classes are from the others (35% of all samples).
#
# This leaves us with something like about 11:1 ratio between the **nv** class and the others.
#
# This problem, can be solved in two different manner:
# - **UnderSampling:** It is the process where you randomly delete some of the observations from the majority class in order to match the numbers with the minority class.
# - **OverSampling:** This second resampling technique is a little more complicated than undersampling. It is the process of generating synthetic data that tries to randomly generate a sample of the attributes from observations in the minority class. There are a number of methods used to oversample a dataset for a typical classification problem.
#
# For facing this problem, we opted for the second technique, **OverSampling**, using the **ResampleFromTheDataset** strategy. This will simply resample the "remaining" samples, up until it has not filled the Gap.
#
# From the **result** of the plot, we can observe that we have now reached a **Uniform Distribution** in the Dataset among all the classes.

# %%
# Declaration of the RandomOverSampler and fitting it.
# oversample = RandomOverSampler()
# x_train,y_train  = oversample.fit_resample(x_train,y_train)
# sns.countplot(y_train)

sm = SMOTE(random_state = 42)
x_train, y_train = sm.fit_resample(x_train, y_train)

# Replotting the dataset, after the SMOTE sampling.
bar, ax = plt.subplots(figsize=(20, 10))
sns.countplot(x = y_train)
plt.title('Disease Class Distribution in the Dataset', size=25)
plt.xlabel('ClassDisease', size=15)
plt.ylabel('NumberOfSamples', size=15)
plt.show()

# %% [markdown]
# # **STEP 6: IMAGE VISUALIZATION**
#
# We can now proceed to have a more in depth **look** at the actual **Image**. We can therefore random sample some image, reshape it, and visualize it.

# %%
# Take one number from 0 to 10000.
n = random.randint(0,10000)

# Reshape it.
x_train_4d=np.array(x_train, dtype=np.uint8).reshape(-1,28,28,3)

# Plotting it.
plt.title("Random Image")
plt.imshow(x_train_4d[n].reshape(28,28,3))
plt.show()

# %% [markdown]
# # **STEP 7: CNN MODEL**
#
# Our first **Model** for solving our **SkinMe Project** is to use a **CNN**(Convolutional Neural Network) that will solve our issue to determine what typology of skin lesion we have.

# %% [markdown]
# ## **STEP 7.1: MODEL BUILDING**
#
# In order to **Build the Model**, we will make use of the following schema:
# - Conv2D
# - MaxPool2D
# - BatchNormalization
# - Conv2D
# - Conv2D
# - MaxPool2D
# - BatchNormalization
# - Conv2D
# - Flatten
# - ...
#
# Note that in the **Dense Layers** we have made use of a very recent **Activation Function**, **MISH**, that has surclassed **ReLu** in our Project with way better results. The **Last Layer** is, of course, a **Softmax** that will return us the class with the highest probability. At the end, we see that we are working with about **500K Parameters**.
#
# Once, we have set the CNN, we load the wieghts, that will be used in such a way to not restart from zero at each time we restart the training. We can then compute the Loss using the **Sparse Categorical Cross Entropy**, and the **Adam Optimizer**.

# %%
# Definition of the MISH function.
def mish(inputs):
    x = tf.nn.softplus(inputs)
    x = tf.nn.tanh(x)
    x = tf.multiply(x, inputs)
    return x

# Let's create the Model.
CNN_Model = Sequential()
CNN_Model.add(Conv2D(16, kernel_size = (3,3), input_shape = (28, 28, 3), activation = 'relu', padding = 'same'))
CNN_Model.add(MaxPool2D(pool_size = (2,2)))
CNN_Model.add(tf.keras.layers.BatchNormalization())
CNN_Model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu'))
CNN_Model.add(Conv2D(64, kernel_size = (3,3), activation = 'relu'))
CNN_Model.add(MaxPool2D(pool_size = (2,2)))
CNN_Model.add(tf.keras.layers.BatchNormalization())
CNN_Model.add(Conv2D(128, kernel_size = (3,3), activation = 'relu'))
CNN_Model.add(Conv2D(256, kernel_size = (3,3), activation = 'relu'))
CNN_Model.add(Flatten())
CNN_Model.add(tf.keras.layers.Dropout(0.2))
CNN_Model.add(Dense(256,activation=mish))
CNN_Model.add(tf.keras.layers.BatchNormalization())
CNN_Model.add(tf.keras.layers.Dropout(0.2))
CNN_Model.add(Dense(128,activation=mish))
CNN_Model.add(tf.keras.layers.BatchNormalization())
CNN_Model.add(Dense(64,activation=mish))
CNN_Model.add(tf.keras.layers.BatchNormalization())
CNN_Model.add(tf.keras.layers.Dropout(0.2))
CNN_Model.add(Dense(32,activation=mish))
CNN_Model.add(tf.keras.layers.BatchNormalization())
CNN_Model.add(Dense(7,activation='softmax'))

# Let's print out the result of the CNN.
CNN_Model.summary()

# Take the weights from the pre-trained versions.
callback = tf.keras.callbacks.ModelCheckpoint(filepath='drive/MyDrive/SkinMeProject/dataset/hmnist_28_28_RGB.csv/CNN_weights.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# Let's Compile the CNN_Model by applying the SparseCategoricalCrossEntropy and Adam Optimizer.
CNN_Model.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(lr=0.001), metrics = ['accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 28, 28, 16)        448
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  batch_normalization_18 (Bat  (None, 14, 14, 16)       64
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 12, 12, 32)        4640
#
#  conv2d_17 (Conv2D)          (None, 10, 10, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  batch_normalization_19 (Bat  (None, 5, 5, 64)         256
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 3, 3, 128)         73856
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 256)         295168
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  batch_normalization_20 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  batch_normalization_21 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  batch_normalization_22 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  batch_normalization_23 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_20 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 504,103
# Trainable params: 502,983
# Non-trainable params: 1,120
# _________________________________________________________________

# %% [markdown]
# ## **7.2 - MODEL FITTING**
#
# Once we have built the model, we can procede to **fit** the **Model** and start therefore the actual Training. We can proceed with a batch-size of 128, and 100 epochs, using also the previous weights.
#
# Once we have done this, also load the weights to the CNN_weights file.

# %%
start_time = datetime.now()
history = CNN_Model.fit(x_train_4d, y_train, validation_split=0.2, batch_size = 128, epochs = 100, shuffle=True, callbacks=[callback])
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))

CNN_Model.load_weights('drive/MyDrive/SkinMeProject/dataset/CNN_weights.h5')
# Out:
# Epoch 1/100
# 235/235 [==============================] - ETA: 0s - loss: 0.8668 - accuracy: 0.6983
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 4s 12ms/step - loss: 0.8668 - accuracy: 0.6983 - val_loss: 2.0029 - val_accuracy: 0.1985
# Epoch 2/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.3308 - accuracy: 0.8895
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3310 - accuracy: 0.8894 - val_loss: 1.2790 - val_accuracy: 0.4395
# Epoch 3/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.2301 - accuracy: 0.9183
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2292 - accuracy: 0.9189 - val_loss: 1.2068 - val_accuracy: 0.4573
# Epoch 4/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9359
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1846 - accuracy: 0.9359 - val_loss: 1.2191 - val_accuracy: 0.4430
# Epoch 5/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1519 - accuracy: 0.9452
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1528 - accuracy: 0.9450 - val_loss: 0.6585 - val_accuracy: 0.6496
# Epoch 6/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9527
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1346 - accuracy: 0.9527 - val_loss: 0.8035 - val_accuracy: 0.5961
# Epoch 7/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9567
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1242 - accuracy: 0.9566 - val_loss: 1.3085 - val_accuracy: 0.4997
# Epoch 8/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9650
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1005 - accuracy: 0.9650 - val_loss: 0.6732 - val_accuracy: 0.7156
# Epoch 9/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1005 - accuracy: 0.9640
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1005 - accuracy: 0.9640 - val_loss: 0.6176 - val_accuracy: 0.7398
# Epoch 10/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0886 - accuracy: 0.9689
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0887 - accuracy: 0.9687 - val_loss: 1.3350 - val_accuracy: 0.5327
# Epoch 11/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0786 - accuracy: 0.9725
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0789 - accuracy: 0.9725 - val_loss: 2.2407 - val_accuracy: 0.3750
# Epoch 12/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9756
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0698 - accuracy: 0.9755 - val_loss: 1.0420 - val_accuracy: 0.6052
# Epoch 13/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0670 - accuracy: 0.9773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0672 - accuracy: 0.9772 - val_loss: 1.5534 - val_accuracy: 0.5213
# Epoch 14/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9822
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0510 - accuracy: 0.9823 - val_loss: 1.4802 - val_accuracy: 0.5225
# Epoch 15/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9805
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0569 - accuracy: 0.9804 - val_loss: 1.0861 - val_accuracy: 0.6112
# Epoch 16/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9800
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0586 - accuracy: 0.9800 - val_loss: 0.5339 - val_accuracy: 0.7944
# Epoch 17/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9856
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0429 - accuracy: 0.9856 - val_loss: 0.6960 - val_accuracy: 0.7532
# Epoch 18/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9851
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0434 - accuracy: 0.9851 - val_loss: 0.7554 - val_accuracy: 0.7173
# Epoch 19/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9862
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0397 - accuracy: 0.9862 - val_loss: 1.1218 - val_accuracy: 0.6496
# Epoch 20/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9874
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0378 - accuracy: 0.9873 - val_loss: 0.5834 - val_accuracy: 0.8080
# Epoch 21/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9887
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0321 - accuracy: 0.9888 - val_loss: 1.1032 - val_accuracy: 0.7047
# Epoch 22/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9884
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0339 - accuracy: 0.9885 - val_loss: 0.5990 - val_accuracy: 0.8068
# Epoch 23/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9890
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0312 - accuracy: 0.9890 - val_loss: 0.5926 - val_accuracy: 0.7949
# Epoch 24/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9876
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0392 - accuracy: 0.9876 - val_loss: 1.5750 - val_accuracy: 0.5545
# Epoch 25/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9880
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0363 - accuracy: 0.9880 - val_loss: 0.7861 - val_accuracy: 0.7620
# Epoch 26/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 0.9927
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0221 - accuracy: 0.9928 - val_loss: 1.2902 - val_accuracy: 0.6832
# Epoch 27/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9906
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 1.0786 - val_accuracy: 0.7126
# Epoch 28/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9922
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 1.5104 - val_accuracy: 0.6400
# Epoch 29/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9898
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0304 - accuracy: 0.9896 - val_loss: 0.7093 - val_accuracy: 0.8021
# Epoch 30/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9939
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.6955 - val_accuracy: 0.8227
# Epoch 31/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9923
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.9405 - val_accuracy: 0.7536
# Epoch 32/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9915
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0257 - accuracy: 0.9915 - val_loss: 0.9201 - val_accuracy: 0.7279
# Epoch 33/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0168 - accuracy: 0.9946
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.5744 - val_accuracy: 0.8582
# Epoch 34/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9937
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 1.0831 - val_accuracy: 0.7411
# Epoch 35/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9932
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.5640 - val_accuracy: 0.8416
# Epoch 36/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9920
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 1.2389 - val_accuracy: 0.6634
# Epoch 37/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9951
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 1.1235 - val_accuracy: 0.7245
# Epoch 38/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9965
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 1.1825 - val_accuracy: 0.7404
# Epoch 39/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9946
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 1.1869 - val_accuracy: 0.7104
# Epoch 40/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0203 - accuracy: 0.9940 - val_loss: 1.4716 - val_accuracy: 0.6590
# Epoch 41/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 0.9933
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.9043 - val_accuracy: 0.7672
# Epoch 42/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9942
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.7116 - val_accuracy: 0.8379
# Epoch 43/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 0.9948
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 1.8759 - val_accuracy: 0.6049
# Epoch 44/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9963
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0142 - accuracy: 0.9963 - val_loss: 0.7374 - val_accuracy: 0.8237
# Epoch 45/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9968
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.9032 - val_accuracy: 0.7805
# Epoch 46/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9942
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 1.7108 - val_accuracy: 0.6473
# Epoch 47/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9954
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.6647 - val_accuracy: 0.8363
# Epoch 48/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9944
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.4235 - val_accuracy: 0.8867
# Epoch 49/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9957
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.3753 - val_accuracy: 0.9045
# Epoch 50/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9956
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 1.3715 - val_accuracy: 0.6938
# Epoch 51/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9950
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.8971 - val_accuracy: 0.7757
# Epoch 52/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9957
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.7846 - val_accuracy: 0.8077
# Epoch 53/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9954
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.2779 - val_accuracy: 0.9231
# Epoch 54/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9969
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 1.0573 - val_accuracy: 0.7586
# Epoch 55/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.9957
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.6735 - val_accuracy: 0.8430
# Epoch 56/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9967
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.8017 - val_accuracy: 0.8117
# Epoch 57/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9983
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.6298 - val_accuracy: 0.8552
# Epoch 58/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9947
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 1.4383 - val_accuracy: 0.6826
# Epoch 59/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9953
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 0.5075 - val_accuracy: 0.8617
# Epoch 60/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 1.3627 - val_accuracy: 0.7184
# Epoch 61/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9979
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 1.8567 - val_accuracy: 0.6343
# Epoch 62/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9968
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.4971 - val_accuracy: 0.8701
# Epoch 63/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9970
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.7767 - val_accuracy: 0.8299
# Epoch 64/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9959
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 1.6831 - val_accuracy: 0.6173
# Epoch 65/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9964
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.2221 - val_accuracy: 0.9390
# Epoch 66/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9958
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.2818 - val_accuracy: 0.9023
# Epoch 67/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9979
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.5649 - val_accuracy: 0.8676
# Epoch 68/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9979
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.4216 - val_accuracy: 0.8999
# Epoch 69/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9976
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.1850 - val_accuracy: 0.9435
# Epoch 70/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9987
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.7742 - val_accuracy: 0.8350
# Epoch 71/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9959
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 1.4683 - val_accuracy: 0.6920
# Epoch 72/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9965
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.5299 - val_accuracy: 0.8766
# Epoch 73/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9953
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 1.5108 - val_accuracy: 0.6827
# Epoch 74/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9971
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 1.0172 - val_accuracy: 0.7735
# Epoch 75/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9981
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.1831 - val_accuracy: 0.9524
# Epoch 76/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9980
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.8989 - val_accuracy: 0.7914
# Epoch 77/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9976
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.4753 - val_accuracy: 0.8852
# Epoch 78/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9967
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.6078 - val_accuracy: 0.8419
# Epoch 79/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9980
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.8311 - val_accuracy: 0.8211
# Epoch 80/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9975
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.8348 - val_accuracy: 0.8040
# Epoch 81/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9978
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 1.0208 - val_accuracy: 0.7751
# Epoch 82/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9982
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.6187 - val_accuracy: 0.8618
# Epoch 83/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9973
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.4765 - val_accuracy: 0.8858
# Epoch 84/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 0.9955
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.6534 - val_accuracy: 0.8403
# Epoch 85/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9972
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.5959 - val_accuracy: 0.8562
# Epoch 86/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9974
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.5579 - val_accuracy: 0.8638
# Epoch 87/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9986
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 2.3129 - val_accuracy: 0.6129
# Epoch 88/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9975
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.5700 - val_accuracy: 0.8664
# Epoch 89/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9973
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 1.1163 - val_accuracy: 0.7547
# Epoch 90/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9979
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.8508 - val_accuracy: 0.7898
# Epoch 91/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9988
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.6778 - val_accuracy: 0.8496
# Epoch 92/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9975
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 1.0580 - val_accuracy: 0.7702
# Epoch 93/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9974
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.9498 - val_accuracy: 0.8066
# Epoch 94/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9978
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.4967 - val_accuracy: 0.8794
# Epoch 95/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9983
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.3889 - val_accuracy: 0.9141
# Epoch 96/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9987
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.4932 - val_accuracy: 0.8855
# Epoch 97/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9983
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 1.6666 - val_accuracy: 0.6762
# Epoch 98/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9980
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 2.1718 - val_accuracy: 0.6520
# Epoch 99/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9967
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0131 - accuracy: 0.9967 - val_loss: 0.4517 - val_accuracy: 0.8855
# Epoch 100/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9984
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.4508 - val_accuracy: 0.9023
# Duration: 0:04:24.130325

# %% [markdown]
# ## **7.3 - MODEL EVALUATION**
#
# We can now see the **Model Evaluation**, i.e., how much the model has gone well. First of all, we observe the **Model Accuracy**. This will print the **Accuracy VS Epochs**. We will print out the plot for Accuracy and Validation.
#
# As a second step of the Model Evaluation, we have to see the **Model Loss**. We therefore print out the plot for **Loss VS Epochs**.
#
# As third step, we will have to compute the predictions of the x-test and compute the Confusion Matrix onto it.

# %%
plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy', size=25)
plt.ylabel('Accuracy', size=15)
plt.xlabel('Epochs', size=15)
plt.legend(['Training', 'Validation'], loc='bottom right')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', size=25)
plt.ylabel('Loss', size=15)
plt.xlabel('Epochs', size=15)
plt.legend(['Training', 'Validation'], loc='bottom right')

# %%
# Compute the Loss, taking the x-test.
x_test_4d=np.array(x_test).reshape(-1,28,28,3)
loss, acc = CNN_Model.evaluate(x_test_4d, y_test, verbose=2)

# Making the Prediction of the x-test using our CNN-Model.
y_pred = CNN_Model.predict(x_test_4d)
y_pred = np.argmax(y_pred, axis=1)

#Computing the Confusion Matrix.
conf_mat = confusion_matrix(y_test, y_pred)
labels_numbers = ['0','1','2','3','4','5','6']
fig, ax = plt.subplots(figsize=(10,10)) 
ax = sns.heatmap(conf_mat, annot=True, cmap='Oranges', linewidths=.9, ax=ax)
ax.set_title('Confusion Matrix\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Dataset Values');
ax.xaxis.set_ticklabels(labels_numbers)
ax.yaxis.set_ticklabels(labels_numbers)
plt.show()
# Out:
# 63/63 - 0s - loss: 0.2036 - accuracy: 0.9521 - 398ms/epoch - 6ms/step
# 63/63 [==============================] - 0s 3ms/step

# %% [markdown]
# ## **STEP 7.4: TESTING THE EXAMPLE**
#
# We can now test with our examples the Model. We can see that, by taing some photos from Internet, it will succeed in every prevision!

# %%
# Get the Image from the folder.
test=PIL.Image.open('drive/MyDrive/SkinMeProject/test_imgs/melanoma1.jpeg')

# Resize the image, and reshape it.
test=test.resize((28,28))
test_img=x_test_4d[1]
test_img=np.array(test).reshape(-1,28,28,3)

# Compute the result-prediction of the gicen image.
test_result=CNN_Model.predict(test_img)
test_result=test_result.tolist()
max_prob=max(test_result[0])

# Take the index of the result in such a way to map it to the result.
test_index=test_result[0].index(max_prob)
print(classes[test_index])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-84-1272746de914> in <module>
#       1 # Get the Image from the folder.
# ----> 2 test=PIL.Image.open('drive/MyDrive/SkinMeProject/test_imgs/melanoma1.jpeg')
#       3
#       4 # Resize the image, and reshape it.
#       5 test=test.resize((28,28))
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/SkinMeProject/test_imgs/melanoma1.jpeg'

# %% [markdown]
# # **STEP 8: LSTM MODEL**
#
# As adversary to the first model we have built, we are going to build an LSTM that will be discovering Diseases in the same way, but using the Long Short Term Memory.

# %% [markdown]
# ## **STEP 8.1: MODEL BUILDING**
#
# In order to **Build LSTM Model**, we will first of all reshape the Train and Test Set in 3d. After this, we will use the **Normalization** trick, in such a way to have the data to be cnetered in the mean and divided by the standard deviation.
#
# After this, we proceed into creating a **One-Hot-Encoding**. Once finished, we can finally Build our **LSTM Network**. Also here, we have that there is the usage of the **Dropout** trick, with the aim to regularize for reducing overfitting. It is an efficient way of performing model averaging, by randomly "dropping out", or omitting, units (both hidden and visible) during the training process of a neural network.

# %%
# Parameters for MNIST dataset
img_rows, img_cols = 28, 28

# Parameters for LSTM network
nb_lstm = 64
nb_time_steps = 28
dim_input_vector = 28

# Reshaping Train and Test set.
x_train_3d = np.array(x_train, dtype=np.uint8).reshape(-1,28,84)
x_test_3d = np.array(x_test, dtype=np.uint8).reshape(-1,28,84)

# Normalization
x_train_3d = (x_train_3d - np.mean(x_train_3d)) / np.std(x_train_3d)
x_test_3d = (x_test_3d - np.mean(x_test_3d)) / np.std(x_test_3d)

# Transform the Data in One-Hot-Encoding
y_train_3d = keras.utils.np_utils.to_categorical(y_train, 7)
y_test_3d = keras.utils.np_utils.to_categorical(y_test, 7)

# Building LSTM network
start = time.time()
LSTM_model = Sequential()
LSTM_model.add(LSTM(nb_lstm, input_shape=(nb_time_steps, 84), return_sequences=True))
LSTM_model.add(Dropout(0.2))
LSTM_model.add(LSTM(nb_lstm, return_sequences=False))
LSTM_model.add(Dropout(0.2))
LSTM_model.add(Dense(7, activation='softmax'))
LSTM_model.summary()

#Start downloading the weights, if any, of pre-trained sessions.
callback = tf.keras.callbacks.ModelCheckpoint(filepath='drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5', monitor='val_acc', mode='max', verbose=1)

# Complie the Model using the same loss function and optimizer of before.
LSTM_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
LSTM_model.load_weights('drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 28, 64)            38144
#
#  dropout_14 (Dropout)        (None, 28, 64)            0
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_21 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 71,623
# Trainable params: 71,623
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **STEP 8.2: MODEL FITTING**
#
# We can now **Fit the Model**, i.e., train it over the 100 epochs.

# %%
start = time.time()
# Fitting the model
history = LSTM_model.fit(x_train_3d, y_train_3d, epochs=100, batch_size=128, callbacks=[callback], validation_split = 0.2)
stop = time.time()
# Out:
# Epoch 1/100
# 235/235 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.9392
# Epoch 1: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 6s 13ms/step - loss: 0.2605 - accuracy: 0.9392 - val_loss: 0.7697 - val_accuracy: 0.7842
# Epoch 2/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9676
# Epoch 2: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1116 - accuracy: 0.9677 - val_loss: 0.7303 - val_accuracy: 0.7789
# Epoch 3/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0892 - accuracy: 0.9737
# Epoch 3: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0892 - accuracy: 0.9737 - val_loss: 0.8339 - val_accuracy: 0.7596
# Epoch 4/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9781
# Epoch 4: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0722 - accuracy: 0.9781 - val_loss: 0.7271 - val_accuracy: 0.7863
# Epoch 5/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9801
# Epoch 5: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0659 - accuracy: 0.9802 - val_loss: 0.6078 - val_accuracy: 0.8211
# Epoch 6/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0634 - accuracy: 0.9808
# Epoch 6: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0634 - accuracy: 0.9807 - val_loss: 0.6832 - val_accuracy: 0.8145
# Epoch 7/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0604 - accuracy: 0.9807
# Epoch 7: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0604 - accuracy: 0.9807 - val_loss: 0.6538 - val_accuracy: 0.8274
# Epoch 8/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9843
# Epoch 8: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0512 - accuracy: 0.9844 - val_loss: 0.4433 - val_accuracy: 0.8697
# Epoch 9/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9866
# Epoch 9: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0426 - accuracy: 0.9867 - val_loss: 0.4731 - val_accuracy: 0.8686
# Epoch 10/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9811
# Epoch 10: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0599 - accuracy: 0.9811 - val_loss: 0.4550 - val_accuracy: 0.8711
# Epoch 11/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9860
# Epoch 11: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0443 - accuracy: 0.9859 - val_loss: 0.6091 - val_accuracy: 0.8352
# Epoch 12/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9864
# Epoch 12: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0433 - accuracy: 0.9864 - val_loss: 0.6099 - val_accuracy: 0.8326
# Epoch 13/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9872
# Epoch 13: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0391 - accuracy: 0.9872 - val_loss: 0.6826 - val_accuracy: 0.8156
# Epoch 14/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9827
# Epoch 14: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0525 - accuracy: 0.9828 - val_loss: 0.6066 - val_accuracy: 0.8310
# Epoch 15/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9873
# Epoch 15: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 0.4898 - val_accuracy: 0.8646
# Epoch 16/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9879
# Epoch 16: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.5825 - val_accuracy: 0.8480
# Epoch 17/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0330 - accuracy: 0.9891
# Epoch 17: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.5253 - val_accuracy: 0.8658
# Epoch 18/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9915
# Epoch 18: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0267 - accuracy: 0.9915 - val_loss: 0.5500 - val_accuracy: 0.8629
# Epoch 19/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9853
# Epoch 19: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0443 - accuracy: 0.9851 - val_loss: 0.6188 - val_accuracy: 0.8447
# Epoch 20/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9862
# Epoch 20: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0406 - accuracy: 0.9862 - val_loss: 0.5673 - val_accuracy: 0.8527
# Epoch 21/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9898
# Epoch 21: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0320 - accuracy: 0.9899 - val_loss: 0.5873 - val_accuracy: 0.8578
# Epoch 22/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9902
# Epoch 22: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0302 - accuracy: 0.9901 - val_loss: 0.7151 - val_accuracy: 0.8376
# Epoch 23/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9901
# Epoch 23: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.5228 - val_accuracy: 0.8665
# Epoch 24/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9916
# Epoch 24: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0285 - accuracy: 0.9914 - val_loss: 0.5825 - val_accuracy: 0.8555
# Epoch 25/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9858
# Epoch 25: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0432 - accuracy: 0.9857 - val_loss: 0.5355 - val_accuracy: 0.8677
# Epoch 26/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9905
# Epoch 26: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.4603 - val_accuracy: 0.8862
# Epoch 27/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9919
# Epoch 27: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 0.4952 - val_accuracy: 0.8824
# Epoch 28/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9924
# Epoch 28: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.4607 - val_accuracy: 0.8835
# Epoch 29/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9861
# Epoch 29: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0423 - accuracy: 0.9859 - val_loss: 0.4768 - val_accuracy: 0.8843
# Epoch 30/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9923
# Epoch 30: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.5308 - val_accuracy: 0.8759
# Epoch 31/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9933
# Epoch 31: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 0.7325 - val_accuracy: 0.8404
# Epoch 32/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9895
# Epoch 32: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0356 - accuracy: 0.9894 - val_loss: 0.6491 - val_accuracy: 0.8520
# Epoch 33/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0270 - accuracy: 0.9911
# Epoch 33: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.4581 - val_accuracy: 0.8888
# Epoch 34/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9949
# Epoch 34: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0174 - accuracy: 0.9948 - val_loss: 0.5799 - val_accuracy: 0.8677
# Epoch 35/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9897
# Epoch 35: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.5192 - val_accuracy: 0.8834
# Epoch 36/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9893
# Epoch 36: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0342 - accuracy: 0.9894 - val_loss: 0.6334 - val_accuracy: 0.8548
# Epoch 37/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9903
# Epoch 37: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0300 - accuracy: 0.9903 - val_loss: 0.7018 - val_accuracy: 0.8384
# Epoch 38/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9932
# Epoch 38: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.6683 - val_accuracy: 0.8556
# Epoch 39/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9927
# Epoch 39: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0239 - accuracy: 0.9926 - val_loss: 0.5282 - val_accuracy: 0.8785
# Epoch 40/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9923
# Epoch 40: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0251 - accuracy: 0.9924 - val_loss: 0.5514 - val_accuracy: 0.8766
# Epoch 41/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9941
# Epoch 41: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.5633 - val_accuracy: 0.8710
# Epoch 42/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9916
# Epoch 42: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.8436 - val_accuracy: 0.8090
# Epoch 43/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9925
# Epoch 43: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.5041 - val_accuracy: 0.8867
# Epoch 44/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9939
# Epoch 44: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0198 - accuracy: 0.9938 - val_loss: 0.7178 - val_accuracy: 0.8481
# Epoch 45/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9936
# Epoch 45: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.5478 - val_accuracy: 0.8771
# Epoch 46/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9884
# Epoch 46: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0366 - accuracy: 0.9882 - val_loss: 0.3820 - val_accuracy: 0.9069
# Epoch 47/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9937
# Epoch 47: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.5206 - val_accuracy: 0.8827
# Epoch 48/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0270 - accuracy: 0.9912
# Epoch 48: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0267 - accuracy: 0.9914 - val_loss: 0.5273 - val_accuracy: 0.8753
# Epoch 49/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9954
# Epoch 49: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.5926 - val_accuracy: 0.8706
# Epoch 50/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9935
# Epoch 50: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0206 - accuracy: 0.9935 - val_loss: 0.5422 - val_accuracy: 0.8786
# Epoch 51/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9928
# Epoch 51: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.6526 - val_accuracy: 0.8613
# Epoch 52/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9919
# Epoch 52: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.5185 - val_accuracy: 0.8894
# Epoch 53/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9949
# Epoch 53: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 0.4523 - val_accuracy: 0.9031
# Epoch 54/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9934
# Epoch 54: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0197 - accuracy: 0.9932 - val_loss: 0.4587 - val_accuracy: 0.8948
# Epoch 55/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9930
# Epoch 55: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.6712 - val_accuracy: 0.8509
# Epoch 56/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9905
# Epoch 56: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 0.6702 - val_accuracy: 0.8593
# Epoch 57/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9934
# Epoch 57: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.6604 - val_accuracy: 0.8593
# Epoch 58/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9896
# Epoch 58: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0336 - accuracy: 0.9896 - val_loss: 0.5491 - val_accuracy: 0.8767
# Epoch 59/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9935
# Epoch 59: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.6125 - val_accuracy: 0.8707
# Epoch 60/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9955
# Epoch 60: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.6184 - val_accuracy: 0.8741
# Epoch 61/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9954
# Epoch 61: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.7094 - val_accuracy: 0.8592
# Epoch 62/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9928
# Epoch 62: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.6203 - val_accuracy: 0.8672
# Epoch 63/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9947
# Epoch 63: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0173 - accuracy: 0.9947 - val_loss: 0.5001 - val_accuracy: 0.8927
# Epoch 64/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9963
# Epoch 64: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.5819 - val_accuracy: 0.8766
# Epoch 65/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9951
# Epoch 65: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0169 - accuracy: 0.9951 - val_loss: 0.6347 - val_accuracy: 0.8711
# Epoch 66/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9908
# Epoch 66: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0296 - accuracy: 0.9910 - val_loss: 0.5741 - val_accuracy: 0.8743
# Epoch 67/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9937
# Epoch 67: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.5791 - val_accuracy: 0.8759
# Epoch 68/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9907
# Epoch 68: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0304 - accuracy: 0.9907 - val_loss: 0.6182 - val_accuracy: 0.8690
# Epoch 69/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.9955
# Epoch 69: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.5785 - val_accuracy: 0.8894
# Epoch 70/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9944
# Epoch 70: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.5279 - val_accuracy: 0.8899
# Epoch 71/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9934
# Epoch 71: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.4383 - val_accuracy: 0.9055
# Epoch 72/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9938
# Epoch 72: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.5098 - val_accuracy: 0.8934
# Epoch 73/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9920
# Epoch 73: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 0.7225 - val_accuracy: 0.8471
# Epoch 74/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9950
# Epoch 74: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.4718 - val_accuracy: 0.9070
# Epoch 75/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9951
# Epoch 75: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.5519 - val_accuracy: 0.8898
# Epoch 76/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9950
# Epoch 76: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.6569 - val_accuracy: 0.8750
# Epoch 77/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9954
# Epoch 77: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 0.5969 - val_accuracy: 0.8815
# Epoch 78/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9933
# Epoch 78: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 0.7033 - val_accuracy: 0.8441
# Epoch 79/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9945
# Epoch 79: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.5444 - val_accuracy: 0.8846
# Epoch 80/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9940
# Epoch 80: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.8796 - val_accuracy: 0.8254
# Epoch 81/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9939
# Epoch 81: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.4767 - val_accuracy: 0.9035
# Epoch 82/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9944
# Epoch 82: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.5511 - val_accuracy: 0.8866
# Epoch 83/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9935
# Epoch 83: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.3890 - val_accuracy: 0.9140
# Epoch 84/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9960
# Epoch 84: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.5619 - val_accuracy: 0.8888
# Epoch 85/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9946
# Epoch 85: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.5031 - val_accuracy: 0.9005
# Epoch 86/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9942
# Epoch 86: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.4299 - val_accuracy: 0.9089
# Epoch 87/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9967
# Epoch 87: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.5757 - val_accuracy: 0.8858
# Epoch 88/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9930
# Epoch 88: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0241 - accuracy: 0.9930 - val_loss: 0.5239 - val_accuracy: 0.8894
# Epoch 89/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9963
# Epoch 89: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.5845 - val_accuracy: 0.8830
# Epoch 90/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9944
# Epoch 90: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.8119 - val_accuracy: 0.8426
# Epoch 91/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9941
# Epoch 91: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.5231 - val_accuracy: 0.8840
# Epoch 92/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9955
# Epoch 92: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.6351 - val_accuracy: 0.8713
# Epoch 93/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9941
# Epoch 93: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.5400 - val_accuracy: 0.8847
# Epoch 94/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9947
# Epoch 94: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 0.6036 - val_accuracy: 0.8803
# Epoch 95/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9966
# Epoch 95: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.5014 - val_accuracy: 0.9044
# Epoch 96/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9957
# Epoch 96: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.5394 - val_accuracy: 0.8904
# Epoch 97/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 0.9960
# Epoch 97: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.5594 - val_accuracy: 0.8927
# Epoch 98/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9925
# Epoch 98: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 0.6268 - val_accuracy: 0.8718
# Epoch 99/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9945
# Epoch 99: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.6113 - val_accuracy: 0.8749
# Epoch 100/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9944
# Epoch 100: saving model to drive/MyDrive/SkinMeProject/dataset/LSTM_weights.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.5128 - val_accuracy: 0.8915

# %% [markdown]
# ## **8.4 - MODEL EVALUATION**
#
# We can now see the **Model Evaluation**, i.e., how much the model has gone well. First of all, we observe the **Model Accuracy**. This will print the **Accuracy VS Epochs**. We will print out the plot for Accuracy and Validation.
#
# As a second step of the Model Evaluation, we have to see the **Model Loss**. We therefore print out the plot for **Loss VS Epochs**.
#
# As third step, we will have to compute the predictions of the x-test and compute the Confusion Matrix onto it.

# %%
plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy', size=25)
plt.ylabel('Accuracy', size=15)
plt.xlabel('Epochs', size=15)
plt.legend(['Training', 'Validation'], loc='bottom right')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', size=25)
plt.ylabel('Loss', size=15)
plt.xlabel('Epochs', size=15)
plt.legend(['Training', 'Validation'], loc='bottom right')

# %%
loss, acc = LSTM_model.evaluate(x_test_3d, y_test_3d, verbose=2)

# Prediction of the LSTM_model Prediction.
y_pred = LSTM_model.predict(x_test_3d)
y_pred = np.argmax(y_pred, axis=1)

# Computation of the actual Confusion Matrix.
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10)) 
ax = sns.heatmap(conf_mat, annot=True, cmap='Greens', linewidths=.9, ax=ax)
ax.set_title('Confusion Matrix\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Dataset Values ');
ax.xaxis.set_ticklabels(labels_numbers)
ax.yaxis.set_ticklabels(labels_numbers)
plt.show()
# Out:
# 63/63 - 0s - loss: 1.6219 - accuracy: 0.7334 - 238ms/epoch - 4ms/step
# 63/63 [==============================] - 1s 3ms/step

# %% [markdown]
# ## **8.4 - TEST EXAMPLE**
#
# We can finally check also here the Test-Image and see that the Network is guessing in the right way the disease.

# %%
test_image=PIL.Image.open('drive/MyDrive/SkinMeProject/test_imgs/tester.jpg')
test_image=test_image.resize((28,28))
test=x_test_3d[1]
test=np.array(test_image).reshape(-1,28,84)
test_result=model.predict(test)
test_result=test_result.tolist()
max_prob=max(test_result[0])
test_index=test_result[0].index(max_prob)
print(classes[test_index])
# Out:
# 1/1 [==============================] - 1s 593ms/step
# ('mel', 'melanoma')
